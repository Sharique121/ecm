# %% [markdown]
# # Various Plots in Python
# - scatter plots
# - histograms
# - KDE
# - errorbars
# - boxplots
# - probplots
# - cumulative density functions
# - regression fits

# %% [markdown]
# ## Getting Things Ready

# %% [raw]
# First, import the libraries that you are going to need. You could also do that later, but it is better style to do that at the beginning. pylab imports the numpy, scipy, and matplotlib.pyplot libraries into the current environment.

# %%
# %pylab inline

import scipy.stats as stats
import seaborn as sns
sns.set_context('notebook')
sns.set_style('darkgrid')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Generate data that are normally distributed
x = randn(50)
x
# Out:
# array([ 0.71377598, -0.66789708, -1.83843338, -0.36504775, -1.56329407,
#         0.58832645, -0.29835943,  1.70903074,  0.12901396, -1.03228538,
#         0.95772569,  0.79056412, -1.23364983,  1.04768194,  0.7308717 ,
#        -0.83342261,  1.38200354,  1.05531022,  1.01380547, -0.63120968,
#        -0.51153357, -2.61403814,  1.69580414, -0.5204939 , -0.46995786,
#         0.14640101,  0.61926608,  0.14028657,  0.46158263, -0.57722174,
#         0.96449176,  0.48637847, -1.45239323,  0.10561845,  1.42248896,
#         1.74019871, -0.01484327,  0.69535054, -2.07082301, -0.06548412,
#         0.25809637,  1.23528937, -0.53616243, -1.58199565,  0.94792991,
#        -2.94698498, -1.79737641,  0.29179592, -0.15772705, -2.05326733])

# %% [markdown]
# ## Scatter Plot

# %%
plot(x,'.')
title('Scatter Plot')
xlabel('X')
ylabel('Y')
draw()

# %% [markdown]
# ## Histogram

# %%
hist(x)
xlabel('Data Values')
ylabel('Frequency')
title('Histogram, default settings')
# Out:
# Text(0.5,1,'Histogram, default settings')

# %%
x = randn(1000)

# %%
hist(x,25)
xlabel('Data Values')
ylabel('Frequency')
title('Histogram, 25 bins')
# Out:
# Text(0.5,1,'Histogram, 25 bins')

# %% [markdown]
# ## KDE - Kernel Density Estimation

# %%
import seaborn as sns
sns.kdeplot(x)
xlabel('Data Values')
ylabel('Density')
# Out:
# Text(0,0.5,'Density')

# %% [markdown]
# ## Cumulative Probability Distribution

# %%
numbins = 20
cdf = stats.cumfreq(x,numbins)
plot(cdf[0])
xlabel('Data Values')
ylabel('Cumulative Frequency')
title('Cumulative probablity density function')
# Out:
# Text(0.5,1,'Cumulative probablity density function')

# %% [markdown]
# ## Box Plot

# %%
# The error bars indicate 1.5* the inter-quartile-range (IQR), and the box consists of the
# first, second (middle) and third quartile
boxplot(x, sym='o')
title('Boxplot')
ylabel('Values')
# Out:
# Text(0,0.5,'Values')

# %% [markdown]
# ### Horizontal Box Plot

# %%
boxplot(x, vert=False, sym='*')
title('Boxplot, horizontal')
xlabel('Values')
# Out:
# Text(0.5,0,'Values')

# %% [markdown]
# ## Error Bars

# %%
x = arange(5)
y = x**2
errorBar = x/2
errorbar(x,y, yerr=errorBar, fmt='o', capsize=5, capthick=3)

plt.xlabel('Data Values')
plt.ylabel('Measurements')
plt.title('Errorbars')

xlim([-0.2, 4.2])
ylim([-0.2, 19])
# Out:
# (-0.2, 19)

# %% [markdown]
# ### Check for Normality

# %%
# Visual check
x = randn(100)
_ = stats.probplot(x, plot=plt)
title('Probplot - check for normality')
# Out:
# Text(0.5,1,'Probplot - check for normality')

# %% [markdown]
# ## 2D Plots

# %%
# Generate data
x = randn(200)
y = 10+0.5*x+randn(len(x))

# Scatter plot
scatter(x,y)
# This one is quite similar to "plot(x,y,'.')"
title('Scatter plot of data')
xlabel('X')
ylabel('Y')
# Out:
# Text(0,0.5,'Y')

# %% [markdown]
# ### Line Fit

# %%
M = vstack((ones(len(x)), x)).T
pars = linalg.lstsq(M,y)[0]
intercept = pars[0]
slope = pars[1]
scatter(x,y)
plot(x, intercept + slope*x, 'r')
show()
